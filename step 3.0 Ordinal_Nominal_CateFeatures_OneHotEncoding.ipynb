# %%
# check imputatopm works

import pandas as pd

data = pd.read_csv('Iterative_sample_posteriorTrue.csv')
data = data.loc[:, ~data.columns.str.contains('^Unnamed')]

# %%
# features applied Multivariate Imputation

col = ['emp_length','mths_since_last_delinq','mths_since_last_record','next_pymnt_d','mths_since_last_major_derog',
       'mths_since_rcnt_il','il_util', 'bc_open_to_buy', 'bc_util', 'mo_sin_old_il_acct','mths_since_recent_bc',
       'mths_since_recent_bc_dlq', 'mths_since_recent_inq', 'mths_since_recent_revol_delinq','percent_bc_gt_75']

# check no missing values

print(data.columns[data.isna().sum() > 0])

# check no float numbers in categorical values

for i in col:
    print(pd.api.types.is_float(i))
# Out:
# Index([], dtype='object')
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
print(list(data.columns))
# Out:
# ['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_length', 'home_ownership', 'annual_inc', 'verification_status', 'issue_d', 'loan_status', 'purpose', 'title', 'zip_code', 'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line', 'inq_last_6mths', 'mths_since_last_delinq', 'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc', 'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt', 'next_pymnt_d', 'last_credit_pull_d', 'collections_12_mths_ex_med', 'mths_since_last_major_derog', 'application_type', 'annual_inc_joint', 'dti_joint', 'verification_status_joint', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m', 'open_act_il', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il', 'total_bal_il', 'il_util', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc', 'all_util', 'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m', 'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util', 'chargeoff_within_12_mths', 'delinq_amnt', 'mo_sin_old_il_acct', 'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl', 'mort_acc', 'mths_since_recent_bc', 'mths_since_recent_bc_dlq', 'mths_since_recent_inq', 'mths_since_recent_revol_delinq', 'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl', 'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl', 'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats', 'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq', 'percent_bc_gt_75', 'pub_rec_bankruptcies', 'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit', 'total_il_high_credit_limit', 'revol_bal_joint', 'sec_app_earliest_cr_line', 'sec_app_inq_last_6mths', 'sec_app_mort_acc', 'sec_app_open_acc', 'sec_app_revol_util', 'sec_app_open_act_il', 'sec_app_num_rev_accts', 'sec_app_chargeoff_within_12_mths', 'sec_app_collections_12_mths_ex_med', 'sec_app_mths_since_last_major_derog', 'hardship_status', 'hardship_amount', 'hardship_loan_status', 'orig_projected_additional_accrued_interest', 'hardship_payoff_balance_amount', 'hardship_last_payment_amount', 'disbursement_method', 'debt_settlement_flag', 'settlement_status', 'settlement_amount', 'settlement_percentage', 'settlement_term']

# %%
data.drop('zip_code',inplace=True,axis=1)

# %%
# categorical feature list without loan_status

categorical_list = ['term',
 'int_rate',
 'grade',
 'sub_grade',
 'emp_length',
 'home_ownership',
 'verification_status',
 'issue_d',
 'purpose',
 'title',
 'addr_state',
 'loan_status',
 'earliest_cr_line',
 'initial_list_status',
 'last_pymnt_d',
 'next_pymnt_d',
 'last_credit_pull_d',
 'application_type',
 'verification_status_joint',
 'sec_app_earliest_cr_line',
 'hardship_status',
 'hardship_loan_status',
 'disbursement_method',
 'debt_settlement_flag',
 'settlement_status']

# %%
#哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈
# obj_df = data.select_dtypes(include=['category']).copy()
# obj_df.head()

# %%
data.groupby(by=['loan_status']).size()
# Out:
# loan_status
# 0.0       591
# 1.0    117603
# 2.0         2
# 3.0      7472
# 4.0       747
# 5.0       276
# 6.0      1503
# dtype: int64

# %% [markdown]
# replace_map = {'loan_status':{"0.0": "Charged Off", "1.0": "Current", "2.0": "Default", "3.0": "Fully Paid", "4.0": "In Grace Period",
#                               "5.0": "Late (16-30 days)", "6.0": "Late (31-120 days)"}}

# %%
data['loan_status'].replace(0.0, "Charged Off", inplace=True)
data['loan_status'].replace(1.0, "Current", inplace=True)
data['loan_status'].replace(2.0, "Default", inplace=True)
data['loan_status'].replace(3.0, "Fully Paid", inplace=True)
data['loan_status'].replace(4.0, "In Grace Period", inplace=True)
data['loan_status'].replace(5.0, "Late (16-30 days)", inplace=True)
data['loan_status'].replace(6.0, "Late (31-120 days)", inplace=True)

# %%
data.groupby(by=['loan_status']).size()
# Out:
# loan_status
# Charged Off              591
# Current               117603
# Default                    2
# Fully Paid              7472
# In Grace Period          747
# Late (16-30 days)        276
# Late (31-120 days)      1503
# dtype: int64

# %%
category = []
header = list(data)
for i in header:
    if data[i].dtype.name == 'category':
        category.append(i)

# %%
data.groupby(by=['emp_length']).size()
# Out:
# emp_length
# -1.0     10387
#  0.0      8295
#  1.0     42035
#  2.0     11407
#  3.0     10540
#  4.0      8238
#  5.0      8103
#  6.0      5750
#  7.0      4629
#  8.0      4311
#  9.0      3146
#  10.0    11353
# dtype: int64

# %%
data['emp_length'].replace(0.0, 11.0, inplace=True)
data['emp_length'].replace(1.0, 12, inplace=True)
data['emp_length'].replace(10.0, 13, inplace=True)

# %%
data['emp_length'].replace(11.0, 1.0, inplace=True)
data['emp_length'].replace(12.0, 10.0, inplace=True)
data['emp_length'].replace(13.0, 0.0, inplace=True)

# %%
data.groupby(by=['emp_length']).size()
# Out:
# emp_length
# -1.0     10387
#  0.0     11353
#  1.0      8295
#  2.0     11407
#  3.0     10540
#  4.0      8238
#  5.0      8103
#  6.0      5750
#  7.0      4629
#  8.0      4311
#  9.0      3146
#  10.0    42035
# dtype: int64

# %%
data.shape
# Out:
# (128194, 122)

# %%
# drop NA > 50% in original dataset
data.drop(columns=['mths_since_last_delinq', 'mths_since_last_record', 'mths_since_last_major_derog', 
                   'mths_since_recent_bc_dlq', 'mths_since_recent_revol_delinq'], axis=1, inplace=True)

# %%
data.groupby(by=['next_pymnt_d']).size()
# Out:
# next_pymnt_d
# -1.0      8063
#  0.0        12
#  1.0        20
#  2.0    120099
# dtype: int64

# %%
data['next_pymnt_d'].replace(0.0, 'Apr-2019', inplace=True)
data['next_pymnt_d'].replace(1.0, 'Feb-2019', inplace=True)
data['next_pymnt_d'].replace(2.0, 'Mar-2019', inplace=True)
data['next_pymnt_d'].replace(-1.0, 'Unkown', inplace=True)

# %%
nominal_data = pd.read_csv('nominal_data.csv')
nominal_data = nominal_data.loc[:, ~nominal_data.columns.str.contains('^Unnamed')]
nominal_data.drop('next_pymnt_d',axis=1, inplace=True)

# %%
nominal_data
# Out:
#               term grade sub_grade home_ownership verification_status  \
# 0        36 months     A        A2       MORTGAGE     Source Verified
# 1        60 months     B        B4       MORTGAGE            Verified
# 2        36 months     A        A4       MORTGAGE        Not Verified
# 3        36 months     A        A3       MORTGAGE            Verified
# 4        36 months     A        A5           RENT            Verified
# 5        36 months     A        A3       MORTGAGE        Not Verified
# 6        36 months     A        A5            OWN        Not Verified
# 7        36 months     D        D2           RENT            Verified
# 8        36 months     A        A2       MORTGAGE     Source Verified
# 9        36 months     C        C4       MORTGAGE            Verified
# 10       60 months     C        C3           RENT     Source Verified
# 11       60 months     D        D2       MORTGAGE        Not Verified
# 12       36 months     C        C2           RENT        Not Verified
# 13       36 months     A        A2            OWN     Source Verified
# 14       60 months     C        C2       MORTGAGE     Source Verified
# 15       60 months     D        D5           RENT     Source Verified
# 16       60 months     A        A4       MORTGAGE     Source Verified
# 17       36 months     A        A5           RENT        Not Verified
# 18       36 months     A        A4           RENT     Source Verified
# 19       36 months     C        C3            OWN     Source Verified
# 20       36 months     A        A4       MORTGAGE        Not Verified
# 21       36 months     A        A2       MORTGAGE        Not Verified
# 22       60 months     C        C3           RENT        Not Verified
# 23       60 months     C        C1       MORTGAGE     Source Verified
# 24       36 months     A        A1       MORTGAGE     Source Verified
# 25       60 months     C        C3            OWN        Not Verified
# 26       36 months     B        B1           RENT        Not Verified
# 27       36 months     B        B4           RENT        Not Verified
# 28       36 months     A        A1           RENT        Not Verified
# 29       60 months     C        C2            OWN            Verified
# ...            ...   ...       ...            ...                 ...
# 128164   36 months     A        A3           RENT     Source Verified
# 128165   36 months     C        C1           RENT     Source Verified
# 128166   36 months     C        C5       MORTGAGE        Not Verified
# 128167   36 months     B        B4       MORTGAGE     Source Verified
# 128168   36 months     D        D5           RENT     Source Verified
# 128169   36 months     A        A1       MORTGAGE        Not Verified
# 128170   36 months     C        C4           RENT     Source Verified
# 128171   36 months     A        A4       MORTGAGE     Source Verified
# 128172   36 months     A        A1           RENT        Not Verified
# 128173   36 months     A        A3           RENT        Not Verified
# 128174   36 months     B        B3           RENT        Not Verified
# 128175   36 months     C        C5           RENT            Verified
# 128176   60 months     A        A4       MORTGAGE     Source Verified
# 128177   60 months     A        A3       MORTGAGE            Verified
# 128178   60 months     B        B4       MORTGAGE            Verified
# 128179   36 months     B        B3            OWN     Source Verified
# 128180   60 months     E        E3       MORTGAGE        Not Verified
# 128181   36 months     B        B4           RENT     Source Verified
# 128182   36 months     B        B5           RENT            Verified
# 128183   36 months     B        B2            OWN        Not Verified
# 128184   60 months     C        C1           RENT     Source Verified
# 128185   60 months     D        D2           RENT        Not Verified
# 128186   36 months     C        C4           RENT        Not Verified
# 128187   36 months     B        B3            OWN        Not Verified
# 128188   36 months     C        C5       MORTGAGE        Not Verified
# 128189   36 months     C        C2            OWN     Source Verified
# 128190   36 months     A        A2           RENT        Not Verified
# 128191   36 months     B        B4           RENT        Not Verified
# 128192   36 months     C        C4       MORTGAGE            Verified
# 128193   36 months     C        C5           RENT     Source Verified
#
#          issue_d             purpose                    title addr_state  \
# 0       Sep-2018         credit_card  Credit card refinancing         NJ
# 1       Sep-2018  debt_consolidation       Debt consolidation         NJ
# 2       Sep-2018         credit_card  Credit card refinancing         WI
# 3       Sep-2018  debt_consolidation       Debt consolidation         FL
# 4       Sep-2018  debt_consolidation       Debt consolidation         NY
# 5       Sep-2018  debt_consolidation       Debt consolidation         SC
# 6       Sep-2018  debt_consolidation       Debt consolidation         IN
# 7       Sep-2018    home_improvement         Home improvement         NY
# 8       Sep-2018  debt_consolidation       Debt consolidation         GA
# 9       Sep-2018    home_improvement         Home improvement         OH
# 10      Sep-2018         credit_card  Credit card refinancing         MA
# 11      Sep-2018  debt_consolidation       Debt consolidation         VA
# 12      Sep-2018  debt_consolidation       Debt consolidation         AZ
# 13      Sep-2018  debt_consolidation       Debt consolidation         NH
# 14      Sep-2018  debt_consolidation       Debt consolidation         CA
# 15      Sep-2018  debt_consolidation       Debt consolidation         WI
# 16      Sep-2018      major_purchase           Major purchase         LA
# 17      Sep-2018             medical         Medical expenses         ME
# 18      Sep-2018         credit_card  Credit card refinancing         FL
# 19      Sep-2018    home_improvement         Home improvement         IL
# 20      Sep-2018  debt_consolidation       Debt consolidation         MN
# 21      Sep-2018               house              Home buying         TX
# 22      Sep-2018  debt_consolidation       Debt consolidation         PA
# 23      Sep-2018         credit_card  Credit card refinancing         NJ
# 24      Sep-2018         credit_card  Credit card refinancing         CA
# 25      Sep-2018  debt_consolidation       Debt consolidation         MO
# 26      Sep-2018  debt_consolidation       Debt consolidation         TN
# 27      Sep-2018  debt_consolidation       Debt consolidation         CA
# 28      Sep-2018  debt_consolidation       Debt consolidation         CA
# 29      Sep-2018  debt_consolidation       Debt consolidation         UT
# ...          ...                 ...                      ...        ...
# 128164  Jul-2018         credit_card  Credit card refinancing         CA
# 128165  Jul-2018  debt_consolidation       Debt consolidation         CA
# 128166  Jul-2018  debt_consolidation       Debt consolidation         AR
# 128167  Jul-2018      small_business                 Business         KS
# 128168  Jul-2018  debt_consolidation       Debt consolidation         CA
# 128169  Jul-2018         credit_card  Credit card refinancing         IL
# 128170  Jul-2018  debt_consolidation       Debt consolidation         NJ
# 128171  Jul-2018  debt_consolidation       Debt consolidation         GA
# 128172  Jul-2018  debt_consolidation       Debt consolidation         NY
# 128173  Jul-2018         credit_card  Credit card refinancing         VA
# 128174  Jul-2018  debt_consolidation       Debt consolidation         FL
# 128175  Jul-2018         credit_card  Credit card refinancing         FL
# 128176  Jul-2018         credit_card  Credit card refinancing         TX
# 128177  Jul-2018  debt_consolidation       Debt consolidation         CT
# 128178  Jul-2018  debt_consolidation       Debt consolidation         FL
# 128179  Jul-2018  debt_consolidation       Debt consolidation         AR
# 128180  Jul-2018         credit_card  Credit card refinancing         CA
# 128181  Jul-2018  debt_consolidation       Debt consolidation         AZ
# 128182  Jul-2018         credit_card  Credit card refinancing         TX
# 128183  Jul-2018  debt_consolidation       Debt consolidation         NC
# 128184  Jul-2018               other                    Other         FL
# 128185  Jul-2018  debt_consolidation       Debt consolidation         FL
# 128186  Jul-2018               other                    Other         NC
# 128187  Jul-2018  debt_consolidation       Debt consolidation         AZ
# 128188  Jul-2018  debt_consolidation       Debt consolidation         TX
# 128189  Jul-2018    home_improvement         Home improvement         NY
# 128190  Jul-2018         credit_card  Credit card refinancing         OK
# 128191  Jul-2018         credit_card  Credit card refinancing         CA
# 128192  Jul-2018  debt_consolidation       Debt consolidation         CA
# 128193  Jul-2018  debt_consolidation       Debt consolidation         CA
#
#        initial_list_status last_pymnt_d last_credit_pull_d application_type  \
# 0                        w     Feb-2019           Feb-2019       Individual
# 1                        w     Feb-2019           Feb-2019       Individual
# 2                        w     Jan-2019           Feb-2019       Individual
# 3                        w     Feb-2019           Feb-2019       Individual
# 4                        w     Feb-2019           Feb-2019       Individual
# 5                        w     Feb-2019           Feb-2019       Individual
# 6                        w     Feb-2019           Feb-2019       Individual
# 7                        w     Feb-2019           Feb-2019       Individual
# 8                        w     Jan-2019           Feb-2019       Individual
# 9                        w     Feb-2019           Feb-2019       Individual
# 10                       w     Jan-2019           Feb-2019       Individual
# 11                       w     Jan-2019           Feb-2019       Individual
# 12                       f     Feb-2019           Feb-2019       Individual
# 13                       w     Feb-2019           Feb-2019       Individual
# 14                       w     Jan-2019           Feb-2019       Individual
# 15                       w     Feb-2019           Feb-2019       Individual
# 16                       w     Feb-2019           Feb-2019       Individual
# 17                       w     Feb-2019           Feb-2019       Individual
# 18                       w     Feb-2019           Feb-2019       Individual
# 19                       w     Feb-2019           Feb-2019       Individual
# 20                       w     Feb-2019           Feb-2019       Individual
# 21                       w     Feb-2019           Feb-2019       Individual
# 22                       w     Feb-2019           Feb-2019       Individual
# 23                       w     Jan-2019           Feb-2019       Individual
# 24                       w     Feb-2019           Feb-2019       Individual
# 25                       w     Feb-2019           Feb-2019       Individual
# 26                       w     Jan-2019           Feb-2019       Individual
# 27                       w     Feb-2019           Feb-2019       Individual
# 28                       w     Feb-2019           Feb-2019       Individual
# 29                       w     Feb-2019           Feb-2019        Joint App
# ...                    ...          ...                ...              ...
# 128164                   f     Jan-2019           Jan-2019       Individual
# 128165                   f     Feb-2019           Feb-2019       Individual
# 128166                   w     Feb-2019           Feb-2019       Individual
# 128167                   w     Feb-2019           Feb-2019       Individual
# 128168                   w     Feb-2019           Feb-2019       Individual
# 128169                   f     Feb-2019           Feb-2019       Individual
# 128170                   f     Feb-2019           Feb-2019       Individual
# 128171                   f     Feb-2019           Feb-2019       Individual
# 128172                   f     Feb-2019           Feb-2019       Individual
# 128173                   f     Feb-2019           Feb-2019       Individual
# 128174                   w     Feb-2019           Feb-2019        Joint App
# 128175                   f     Feb-2019           Feb-2019       Individual
# 128176                   f     Feb-2019           Feb-2019        Joint App
# 128177                   f     Feb-2019           Feb-2019       Individual
# 128178                   w     Feb-2019           Feb-2019       Individual
# 128179                   w     Feb-2019           Feb-2019       Individual
# 128180                   w     Feb-2019           Feb-2019       Individual
# 128181                   w     Feb-2019           Feb-2019       Individual
# 128182                   w     Sep-2018           Sep-2018       Individual
# 128183                   w     Feb-2019           Feb-2019       Individual
# 128184                   w     Feb-2019           Feb-2019       Individual
# 128185                   w     Oct-2018           Feb-2019       Individual
# 128186                   w     Feb-2019           Feb-2019       Individual
# 128187                   w     Feb-2019           Feb-2019       Individual
# 128188                   w     Feb-2019           Feb-2019       Individual
# 128189                   w     Feb-2019           Feb-2019       Individual
# 128190                   w     Feb-2019           Feb-2019       Individual
# 128191                   w     Feb-2019           Feb-2019       Individual
# 128192                   w     Feb-2019           Feb-2019       Individual
# 128193                   w     Feb-2019           Feb-2019       Individual
#
#        verification_status_joint hardship_status hardship_loan_status  \
# 0                             No              No                   No
# 1                             No              No                   No
# 2                             No              No                   No
# 3                             No              No                   No
# 4                             No              No                   No
# 5                             No              No                   No
# 6                             No              No                   No
# 7                             No              No                   No
# 8                             No              No                   No
# 9                             No              No                   No
# 10                            No              No                   No
# 11                            No              No                   No
# 12                            No              No                   No
# 13                            No              No                   No
# 14                            No              No                   No
# 15                            No              No                   No
# 16                            No              No                   No
# 17                            No              No                   No
# 18                            No              No                   No
# 19                            No              No                   No
# 20                            No              No                   No
# 21                            No              No                   No
# 22                            No              No                   No
# 23                            No              No                   No
# 24                            No              No                   No
# 25                            No              No                   No
# 26                            No              No                   No
# 27                            No              No                   No
# 28                            No              No                   No
# 29                      Verified              No                   No
# ...                          ...             ...                  ...
# 128164                        No              No                   No
# 128165                        No              No                   No
# 128166                        No              No                   No
# 128167                        No              No                   No
# 128168                        No              No                   No
# 128169                        No              No                   No
# 128170                        No              No                   No
# 128171                        No              No                   No
# 128172                        No              No                   No
# 128173                        No              No                   No
# 128174              Not Verified              No                   No
# 128175                        No              No                   No
# 128176           Source Verified              No                   No
# 128177                        No              No                   No
# 128178                        No              No                   No
# 128179                        No              No                   No
# 128180                        No              No                   No
# 128181                        No              No                   No
# 128182                        No              No                   No
# 128183                        No              No                   No
# 128184                        No              No                   No
# 128185                        No              No                   No
# 128186                        No              No                   No
# 128187                        No              No                   No
# 128188                        No              No                   No
# 128189                        No              No                   No
# 128190                        No              No                   No
# 128191                        No              No                   No
# 128192                        No              No                   No
# 128193                        No              No                   No
#
#        disbursement_method debt_settlement_flag settlement_status
# 0                DirectPay                    N                No
# 1                     Cash                    N                No
# 2                     Cash                    N                No
# 3                     Cash                    N                No
# 4                     Cash                    N                No
# 5                     Cash                    N                No
# 6                     Cash                    N                No
# 7                     Cash                    N                No
# 8                     Cash                    N                No
# 9                     Cash                    N                No
# 10                    Cash                    N                No
# 11                    Cash                    N                No
# 12                    Cash                    N                No
# 13                    Cash                    N                No
# 14                    Cash                    N                No
# 15                    Cash                    N                No
# 16                    Cash                    N                No
# 17                    Cash                    N                No
# 18               DirectPay                    N                No
# 19                    Cash                    N                No
# 20                    Cash                    N                No
# 21                    Cash                    N                No
# 22                    Cash                    N                No
# 23                    Cash                    N                No
# 24               DirectPay                    N                No
# 25                    Cash                    N                No
# 26                    Cash                    N                No
# 27                    Cash                    N                No
# 28               DirectPay                    N                No
# 29                    Cash                    N                No
# ...                    ...                  ...               ...
# 128164                Cash                    N                No
# 128165                Cash                    N                No
# 128166                Cash                    N                No
# 128167                Cash                    N                No
# 128168                Cash                    N                No
# 128169           DirectPay                    N                No
# 128170                Cash                    N                No
# 128171                Cash                    N                No
# 128172                Cash                    N                No
# 128173                Cash                    N                No
# 128174                Cash                    N                No
# 128175                Cash                    N                No
# 128176                Cash                    N                No
# 128177           DirectPay                    N                No
# 128178                Cash                    N                No
# 128179                Cash                    N                No
# 128180                Cash                    N                No
# 128181                Cash                    N                No
# 128182                Cash                    N                No
# 128183                Cash                    N                No
# 128184                Cash                    N                No
# 128185                Cash                    N                No
# 128186                Cash                    N                No
# 128187                Cash                    N                No
# 128188                Cash                    N                No
# 128189                Cash                    N                No
# 128190                Cash                    N                No
# 128191                Cash                    N                No
# 128192                Cash                    N                No
# 128193                Cash                    N                No
#
# [128194 rows x 19 columns]

# %%
ordinal = ['int_rate', 'emp_length', 'earliest_cr_line', 'sec_app_earliest_cr_line']
nominal = ['term',
 'grade',
 'sub_grade',
 'home_ownership',
 'verification_status',
 'issue_d',
 'purpose',
 'title',
 'addr_state',
 'initial_list_status',
 'last_pymnt_d',
 'last_credit_pull_d',
 'application_type',
 'verification_status_joint',
 'hardship_status',
 'hardship_loan_status',
 'disbursement_method',
 'debt_settlement_flag',
 'settlement_status']

# %%
data.drop(columns=nominal, axis=1, inplace=True)

# %%
data = pd.concat([data, nominal_data], axis=1)

# %%
# one-hot encoding

data = pd.get_dummies(data, columns=nominal, prefix=nominal)
data = pd.get_dummies(data, columns=['next_pymnt_d'], prefix=['next_pymnt_d'])

# %%
data.shape
# Out:
# (128194, 268)

# %%
data.to_csv('one_hot_encoded_data.csv')

# %%
for i in list(data.columns):
    print(data[i].dtype)
# Out:
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# object
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8

# %%
data_target = data['loan_status']
data.drop('loan_status',inplace=True, axis=1)
data_input = data
